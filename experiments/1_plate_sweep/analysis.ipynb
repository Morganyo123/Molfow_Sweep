# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.rcParams.update({
    "font.size": 11,
    "font.family": "serif",
    "axes.labelsize": 12,
    "axes.titlesize": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "figure.dpi": 150,
    "savefig.dpi": 300,
})

# %%
df = pd.read_csv("position_sweep_summary_10_7.csv")

# %%
df.head()
# Out:
#    offset  back_efficiency  collection_efficiency  front_share  \
# 0     0.0         0.037442               0.517961     0.927713
# 1     0.5         0.044945               0.390496     0.884903
# 2     1.0         0.047597               0.313620     0.848234
# 3     1.5         0.049000               0.267475     0.816805
# 4     2.0         0.048908               0.235067     0.791940
#
#    plate_back_equiv_abs  plate_back_imping_rate  plate_back_mc_hits  \
# 0               37442.0            1.718909e+18             37442.0
# 1               44945.0            2.063361e+18             44945.0
# 2               47597.0            2.185111e+18             47597.0
# 3               49000.0            2.249521e+18             49000.0
# 4               48908.0            2.245297e+18             48908.0
#
#    plate_front_equiv_abs  plate_front_imping_rate  plate_front_mc_hits  \
# 0               480519.0             2.205995e+19             480519.0
# 1               345551.0             1.586376e+19             345551.0
# 2               266023.0             1.221274e+19             266023.0
# 3               218475.0             1.002988e+19             218475.0
# 4               186159.0             8.546297e+18             186159.0
#
#    ratio_front_back  total_des  error
# 0         12.833689  1000000.0    NaN
# 1          7.688308  1000000.0    NaN
# 2          5.589071  1000000.0    NaN
# 3          4.458673  1000000.0    NaN
# 4          3.806310  1000000.0    NaN

# %%
plt.plot(df["offset"], df["plate_back_imping_rate"], marker="o",label="Back Impingement Rate")
plt.xlabel("Offset [cm]")
plt.ylabel("Impingement Rate")
plt.grid()
plt.legend()

# %%
plt.plot(df["offset"], df["plate_front_imping_rate"], marker="o",label="Front Impingement Rate")
plt.xlabel("Offset [cm]")
plt.ylabel("Impingement Rate")
plt.grid(True)
plt.legend()

# %%
fig, ax = plt.subplots(2, 1, figsize=(8, 6))
ax[0].plot(df["offset"], df["plate_back_imping_rate"], marker="o", ms=4, lw=1.2, color="#1f77b4")
ax[0].set_ylabel("Back rate\n[hits/s]")
ax[0].tick_params(axis="y", which="major", labelsize=10,)
ax[0].grid(alpha=0.3)

ax[1].plot(df["offset"], df["plate_front_imping_rate"], marker="o", ms=4, lw=1.2, color="#d62728")
ax[1].set_ylabel("Front rate\n[hits/s]")
ax[1].grid(alpha=0.3, which="both")
ax[1].set_xlabel("Plate offset [cm]")

plt.savefig("position_sweep_impingement_rates.png", dpi=300, bbox_inches="tight")
