# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({
    "font.size": 11,
    "font.family": "serif",
    "axes.labelsize": 12,
    "axes.titlesize": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "figure.dpi": 150,
    "savefig.dpi": 300,
})

# %%
df = pd.read_csv("summary.csv")

# %%
index = pd.read_csv(r"sweep_runs\run_index.csv")

# %%
df
# Out:
#     c10_equiv_abs  c10_imping_rate  c10_mc_hits  c11_equiv_abs  \
# 0             0.0     3.917212e+18       3243.0            0.0
# 1             0.0     3.332589e+18       2759.0            0.0
# 2             0.0     2.942438e+18       2436.0            0.0
# 3             0.0     2.495516e+18       2066.0            0.0
# 4             0.0     2.224947e+18       1842.0            0.0
# 5             0.0     4.544111e+18       3762.0            0.0
# 6             0.0     3.873727e+18       3207.0            0.0
# 7             0.0     3.487200e+18       2887.0            0.0
# 8             0.0     3.134494e+18       2595.0            0.0
# 9             0.0     2.896538e+18       2398.0            0.0
# 10            0.0     4.308571e+18       3567.0            0.0
# 11            0.0     3.841114e+18       3180.0            0.0
# 12            0.0     3.467874e+18       2871.0            0.0
# 13            0.0     3.269779e+18       2707.0            0.0
# 14            0.0     3.176771e+18       2630.0            0.0
# 15            0.0     3.983646e+18       3298.0            0.0
# 16            0.0     3.698582e+18       3062.0            0.0
# 17            0.0     3.477537e+18       2879.0            0.0
# 18            0.0     3.241997e+18       2684.0            0.0
# 19            0.0     3.099465e+18       2566.0            0.0
# 20            0.0     3.792798e+18       3140.0            0.0
# 21            0.0     3.603158e+18       2983.0            0.0
# 22            0.0     3.383321e+18       2801.0            0.0
# 23            0.0     3.105505e+18       2571.0            0.0
# 24            0.0     3.165900e+18       2621.0            0.0
# 25            0.0     3.599535e+18       2980.0            0.0
# 26            0.0     3.514982e+18       2910.0            0.0
# 27            0.0     3.275818e+18       2712.0            0.0
# 28            0.0     3.100673e+18       2567.0            0.0
# 29            0.0     3.007665e+18       2490.0            0.0
# 30            0.0     3.457003e+18       2862.0            0.0
# 31            0.0     3.420766e+18       2832.0            0.0
# 32            0.0     3.171939e+18       2626.0            0.0
# 33            0.0     3.092218e+18       2560.0            0.0
# 34            0.0     3.051149e+18       2526.0            0.0
# 35            0.0     3.473913e+18       2876.0            0.0
# 36            0.0     3.286689e+18       2721.0            0.0
# 37            0.0     3.251660e+18       2692.0            0.0
# 38            0.0     3.128455e+18       2590.0            0.0
# 39            0.0     2.990754e+18       2476.0            0.0
# 40            0.0     3.266155e+18       2704.0            0.0
# 41            0.0     3.209384e+18       2657.0            0.0
# 42            0.0     3.072891e+18       2544.0            0.0
# 43            0.0     3.022160e+18       2502.0            0.0
# 44            0.0     3.070476e+18       2542.0            0.0
# 45            0.0     3.136910e+18       2597.0            0.0
# 46            0.0     2.976260e+18       2464.0            0.0
# 47            0.0     3.035447e+18       2513.0            0.0
# 48            0.0     2.938815e+18       2433.0            0.0
# 49            0.0     2.896538e+18       2398.0            0.0
# 50            0.0     3.001625e+18       2485.0            0.0
# 51            0.0     3.045110e+18       2521.0            0.0
# 52            0.0     2.863925e+18       2371.0            0.0
# 2                 49316.0             2.264028e+19              49316.0
# 3                 48831.0             2.241762e+19              48831.0
# 4                 48632.0             2.232626e+19              48632.0
# 5                 37657.0             1.728780e+19              37657.0
# 6                 36882.0             1.693201e+19              36882.0
# 7                 36310.0             1.666941e+19              36310.0
# 8                 35912.0             1.648669e+19              35912.0
# 9                 35446.0             1.627276e+19              35446.0
# 10                29163.0             1.338832e+19              29163.0
# 11                28466.0             1.306834e+19              28466.0
# 12                27846.0             1.278371e+19              27846.0
# 13                27961.0             1.283650e+19              27961.0
# 14                27645.0             1.269143e+19              27645.0
# 15                23699.0             1.087988e+19              23699.0
# 16                23036.0             1.057550e+19              23036.0
# 17                23274.0             1.068476e+19              23274.0
# 18                22934.0             1.052868e+19              22934.0
# 19                22900.0             1.051307e+19              22900.0
# 20                20415.0             9.372238e+18              20415.0
# 21                19856.0             9.115609e+18              19856.0
# 22                19752.0             9.067864e+18              19752.0
# 23                19530.0             8.965947e+18              19530.0
# 24                19553.0             8.976506e+18              19553.0
# 25                17605.0             8.082207e+18              17605.0
# 26                17418.0             7.996358e+18              17418.0
# 27                17156.0             7.876077e+18              17156.0
# 28                17092.0             7.846696e+18              17092.0
# 29                17439.0             8.005999e+18              17439.0
# 30                15840.0             7.271920e+18              15840.0
# 31                15730.0             7.221421e+18              15730.0
# 32                15528.0             7.128685e+18              15528.0
# 33                15678.0             7.197548e+18              15678.0
# 34                15606.0             7.164494e+18              15606.0
# 35                14473.0             6.644350e+18              14473.0
# 36                14362.0             6.593391e+18              14362.0
# 37                14265.0             6.548860e+18              14265.0
# 38                14290.0             6.560337e+18              14290.0
# 39                14215.0             6.525906e+18              14215.0
# 40                13659.0             6.270654e+18              13659.0
# 41                13384.0             6.144405e+18              13384.0
# 42                13397.0             6.150373e+18              13397.0
# 43                13224.0             6.070952e+18              13224.0
# 44                13088.0             6.008516e+18              13088.0
# 45                12469.0             5.724342e+18              12469.0
# 46                12348.0             5.668792e+18              12348.0
# 47                12500.0             5.738573e+18              12500.0
# 48                12298.0             5.645838e+18              12298.0
# 49                12376.0             5.681647e+18              12376.0
# 50                12021.0             5.518671e+18              12021.0
# 51                11803.0             5.418591e+18              11803.0
# 52                11598.0             5.324478e+18              11598.0
# 53                11641.0             5.344219e+18              11641.0
# 54                11725.0             5.382782e+18              11725.0
#
#     total_des  error
# 0    100000.0    NaN
# 1    100000.0    NaN
# 2    100000.0    NaN
# 3    100000.0    NaN
# 4    100000.0    NaN
# 5    100000.0    NaN
# 6    100000.0    NaN
# 7    100000.0    NaN
# 8    100000.0    NaN
# 9    100000.0    NaN
# 10   100000.0    NaN
# 11   100000.0    NaN
# 12   100000.0    NaN
# 13   100000.0    NaN
# 14   100000.0    NaN
# 15   100000.0    NaN
# 16   100000.0    NaN
# 17   100000.0    NaN
# 18   100000.0    NaN
# 19   100000.0    NaN
# 20   100000.0    NaN
# 21   100000.0    NaN
# 22   100000.0    NaN
# 23   100000.0    NaN
# 24   100000.0    NaN
# 25   100000.0    NaN
# 26   100000.0    NaN
# 27   100000.0    NaN
# 28   100000.0    NaN
# 29   100000.0    NaN
# 30   100000.0    NaN
# 31   100000.0    NaN
# 32   100000.0    NaN
# 33   100000.0    NaN
# 34   100000.0    NaN
# 35   100000.0    NaN
# 36   100000.0    NaN
# 37   100000.0    NaN
# 38   100000.0    NaN
# 39   100000.0    NaN
# 40   100000.0    NaN
# 41   100000.0    NaN
# 42   100000.0    NaN
# 43   100000.0    NaN
# 44   100000.0    NaN
# 45   100000.0    NaN
# 46   100000.0    NaN
# 47   100000.0    NaN
# 48   100000.0    NaN
# 49   100000.0    NaN
# 50   100000.0    NaN
# 51   100000.0    NaN
# 52   100000.0    NaN
# 53   100000.0    NaN
# 54   100000.0    NaN
#
# [55 rows x 125 columns]

# %%
plt.plot(df['plate_back_equiv_abs'],"x-")

# %%
plt.plot(df['plate_front_equiv_abs'],"x-")

# %%
index.head()
# Out:
#                  run_id                                              moves  \
# 0  Plate_0.0_Cone_-0.25  [(['plate_front', 'plate_back'], 0, 0.0), (['c...
# 1    Plate_0.0_Cone_0.0  [(['plate_front', 'plate_back'], 0, 0.0), (['c...
# 2   Plate_0.0_Cone_0.25  [(['plate_front', 'plate_back'], 0, 0.0), (['c...
# 3    Plate_0.0_Cone_0.5  [(['plate_front', 'plate_back'], 0, 0.0), (['c...
# 4   Plate_0.0_Cone_0.75  [(['plate_front', 'plate_back'], 0, 0.0), (['c...
#
#                                              run_dir
# 0  C:\Users\morga\Documents\CERN\Molfow_Sweep\exp...
# 1  C:\Users\morga\Documents\CERN\Molfow_Sweep\exp...
# 2  C:\Users\morga\Documents\CERN\Molfow_Sweep\exp...
# 3  C:\Users\morga\Documents\CERN\Molfow_Sweep\exp...
# 4  C:\Users\morga\Documents\CERN\Molfow_Sweep\exp...

# %%
dist = []

plate_dist = 0
cone_dist = 0


#construct plate and distance pattern
for i in range(11):
    cone_dist = plate_dist - 0.25
    for i in range(5):
        dist.append([plate_dist, cone_dist])
        cone_dist += 0.25 

    cone_dist = -0.25
    plate_dist += 0.5

print(dist)
# Out:
# [[0, -0.25], [0, 0.0], [0, 0.25], [0, 0.5], [0, 0.75], [0.5, 0.25], [0.5, 0.5], [0.5, 0.75], [0.5, 1.0], [0.5, 1.25], [1.0, 0.75], [1.0, 1.0], [1.0, 1.25], [1.0, 1.5], [1.0, 1.75], [1.5, 1.25], [1.5, 1.5], [1.5, 1.75], [1.5, 2.0], [1.5, 2.25], [2.0, 1.75], [2.0, 2.0], [2.0, 2.25], [2.0, 2.5], [2.0, 2.75], [2.5, 2.25], [2.5, 2.5], [2.5, 2.75], [2.5, 3.0], [2.5, 3.25], [3.0, 2.75], [3.0, 3.0], [3.0, 3.25], [3.0, 3.5], [3.0, 3.75], [3.5, 3.25], [3.5, 3.5], [3.5, 3.75], [3.5, 4.0], [3.5, 4.25], [4.0, 3.75], [4.0, 4.0], [4.0, 4.25], [4.0, 4.5], [4.0, 4.75], [4.5, 4.25], [4.5, 4.5], [4.5, 4.75], [4.5, 5.0], [4.5, 5.25], [5.0, 4.75], [5.0, 5.0], [5.0, 5.25], [5.0, 5.5], [5.0, 5.75]]

# %%
intensity = df['plate_back_imping_rate'] 
x = []
y = []


for pair in dist:
    x.append(pair[0])
    y.append(pair[1])

# %%
plt.tricontourf(x, y, intensity, levels=500)
plt.xlabel("plate distance (cm)")
plt.ylabel("cone distance (cm)")
plt.title("Intensity Distribution")
plt.colorbar(label="Intensity")
plt.show();
# Out:
# c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\series.py:899: RuntimeWarning: invalid value encountered in cast
#   arr = np.asarray(values, dtype=dtype)

# %%
dist = np.array(dist)
intensity = np.array(df['plate_back_equiv_abs'] / df['total_des'])

plate = dist[:, 0]
cone = dist[:, 1]
offset = np.round(cone - plate, 2)

fig, ax = plt.subplots()

for o in np.unique(offset):
    mask = offset == o
    order = np.argsort(plate[mask])
    ax.plot(plate[mask][order], intensity[mask][order], 'x-', label=f'{o}')

ax.set_xlabel('Plate distance [cm]')
ax.set_ylabel('Hit Fraction')
ax.legend(title='Cone offset [cm]',fontsize=8)
ax.grid()
plt.show()

# %% [markdown]
# ## Comparison with no cone

# %%
df2 = pd.read_csv("position_sweep_summary_with_deflector.csv")

# %%
fig, ax = plt.subplots()

for o in np.unique(offset):
    mask = offset == o
    order = np.argsort(plate[mask])
    ax.plot(plate[mask][order], intensity[mask][order], 'x-', label=f'{o}')



mask = df2['offset'] <= 5
ax.plot(df2['offset'][mask], df2["plate_back_equiv_abs"][mask]/df2["total_des"][mask], "x-", label="No Cone", color="black")
ax.set_xlabel('Plate distance [cm]')
ax.set_ylabel('Hit Fraction')
ax.legend(title='Cone offset [cm]',loc="best", fontsize=8)
ax.grid()
plt.savefig("cone_plate_sweep.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Add Errors?
#
# Assume error is related to poisson error on number of hits on the back plate. $1/\sqrt{N}$

# %%
fig, ax = plt.subplots()

for o in np.unique(offset):
    mask = offset == o
    order = np.argsort(plate[mask])
    ax.errorbar(plate[mask][order], intensity[mask][order], yerr=intensity[mask][order]/np.sqrt(df["plate_back_mc_hits"][mask]), fmt="x-", label=f'{o}')



no_cone_intensity = df2["plate_back_equiv_abs"]/df2["total_des"]
mask = df2['offset'] <= 5
ax.errorbar(df2['offset'][mask], no_cone_intensity[mask], yerr=no_cone_intensity[mask]/np.sqrt(df2["plate_back_mc_hits"][mask]), fmt="x-", label="No Cone", color="black")

ax.set_xlabel('Plate distance [cm]')
ax.set_ylabel('Hit Fraction')
ax.legend(title='Cone offset [cm]',loc="best", fontsize=8)
ax.grid()
plt.savefig("cone_plate_sweep.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Deflector Hits

# %%
fig, ax = plt.subplots()

intensity = np.array(df['deflector_imping_rate'])

for o in np.unique(offset):
    mask = offset == o
    order = np.argsort(plate[mask])
    ax.errorbar(plate[mask][order], intensity[mask][order], yerr=intensity[mask][order]/np.sqrt(df["plate_back_mc_hits"][mask]), fmt="x-", label=f'{o}')

ax.set_xlabel('Plate distance [cm]')
ax.set_ylabel('Deflector Imingement Rate [hits/s]')
ax.legend(title='Cone offset [cm]',loc="best", fontsize=8)
ax.grid()
plt.savefig("cone_plate_sweep_deflector.png", dpi=300, bbox_inches='tight')
